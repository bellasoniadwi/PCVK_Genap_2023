# %% [markdown]
# <a href="https://colab.research.google.com/github/bellasoniadwi/PCVK_Genap_2023/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

#Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_BSDA/Images/kitten01.jpg')
plt.imshow(img)                              #perhatikan hasilnya adalah citra dengan channel warna BGR

# %%
img = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)   #konversi channel BGR  ->  RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_BSDA/Images/kitten01.jpg',cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(img_gray,cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB),(512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

# simpan file image
# cv.imwrite('/content/drive/MyDrive/PCVK_BSDA/Images/mandrill2.tiff',img5)

# tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10)) # ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(400,400),radius=50,color=(255,0,0),thickness=-1)
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
# Tugas nomor 2
# Red-Blue
plt.imshow(img_gray,cmap='RdBu')

# %%
# Green-Blue
plt.imshow(img_gray,cmap='GnBu')

# %%
# Tugas Nomor 3
img = cv.imread('/content/drive/MyDrive/PCVK_BSDA/Images/kitten01.jpg') 
img_rgb = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img_t2 = img_rgb[20:115,25:120]
plt.imshow(img_t2)

# %%
# Tugas Nomor 4
img_t3 = cv.imread('/content/drive/MyDrive/PCVK_BSDA/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)

plt.imshow(img_t3[5:30], cmap='Reds')

# %%
# Tugas Nomor 5
img = cv.imread('/content/drive/MyDrive/PCVK_BSDA/Images/kitten01.jpg')
img_t4 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_t4, pt1=(320,300), pt2=(400,170), color=(0,255,255), thickness=10)
cv.rectangle(img_t4, pt1=(600,100), pt2=(450,200), color=(0,255,0),thickness=10)
cv.rectangle(img_t4, pt1=(400,400), pt2=(600,340), color=(255,255,255),thickness=10)
cv.rectangle(img_t4, pt1=(100,350), pt2=(300,400), color=(255,0,0),thickness=10)
cv.rectangle(img_t4, pt1=(50,150), pt2=(200,300), color=(0,0,255),thickness=10)
plt.imshow(img_t4)

# %%
# Tugas Nomor 6
img_t5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)
ax.imshow(img_t5)

# %%
# Tugas Nomor 7
img = cv.imread('/content/drive/MyDrive/PCVK_BSDA/Images/kitten01.jpg')
img_t6 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_t6,pt1=(420,80), pt2=(600,250),color=(0,0,255),thickness=15)
cv.circle(img_t6,center=(500,160),radius=90,color=(255,0,0),thickness=8)
plt.imshow(img_t6)

# %%
# Tugas Nomor 8
img = cv.imread('/content/drive/MyDrive/PCVK_BSDA/Images/kitten01.jpg')
img_t6 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_t6,pt1=(420,80), pt2=(600,250),color=(0,0,255),thickness=15)
cv.circle(img_t6,center=(500,160),radius=90,color=(255,0,0),thickness=8)
cv.rectangle(img_t6,pt1=(10,400), pt2=(100,480),color=(0,255,0),thickness=15)
plt.imshow(img_t6)
